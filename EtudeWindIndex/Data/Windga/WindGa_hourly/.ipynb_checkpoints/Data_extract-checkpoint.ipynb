# %% [markdown]
# # Instalations

# %%
pip install pymysql sqlalchemy-redshift pykeepass
# Out:
# Requirement already satisfied: pymysql in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.0.2)
# Requirement already satisfied: sqlalchemy-redshift in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (0.8.9)
# Requirement already satisfied: pykeepass in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (4.0.1)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sqlalchemy-redshift) (21.3)
# Requirement already satisfied: SQLAlchemy<2.0.0,>=0.9.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sqlalchemy-redshift) (1.4.31)
# Requirement already satisfied: lxml in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pykeepass) (4.6.4)
# Requirement already satisfied: pycryptodomex>=3.6.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pykeepass) (3.14.0)
# Requirement already satisfied: future in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pykeepass) (0.18.2)
# Requirement already satisfied: argon2-cffi in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pykeepass) (20.1.0)
# Requirement already satisfied: python-dateutil in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pykeepass) (2.8.1)
# Requirement already satisfied: construct==2.10.54 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pykeepass) (2.10.54)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from SQLAlchemy<2.0.0,>=0.9.2->sqlalchemy-redshift) (1.1.2)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from SQLAlchemy<2.0.0,>=0.9.2->sqlalchemy-redshift) (3.7.0)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from argon2-cffi->pykeepass) (1.15.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from argon2-cffi->pykeepass) (1.14.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging->sqlalchemy-redshift) (2.4.7)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from cffi>=1.0.0->argon2-cffi->pykeepass) (2.20)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata->SQLAlchemy<2.0.0,>=0.9.2->sqlalchemy-redshift) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata->SQLAlchemy<2.0.0,>=0.9.2->sqlalchemy-redshift) (4.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pykeepass import PyKeePass
import logging
import getpass
import os
from datetime import datetime
import pandas as pd
import numpy as np
import sqlalchemy
import matplotlib.pyplot as plt
import seaborn as sns
import boto3 #Save in S3
from pathlib import Path

# %%
S3_bucket_name = 'edfred-edfre-sbx-eu-west-1-solar-radiation-data'
S3_CSV_FOLD = r'EtudeWindIndex/Real'

# %% [markdown]
# # Accès aux données Keepass

# %%
#Get logging information stored in keepass
Configuration_path = Path('/home/ec2-user/SageMaker/EtudeWindIndex/Data/Windga/WindGa_hourly/Configuration')
KEEPASS_FILE = Configuration_path/'RDL.kdbx'

logging.basicConfig(format=' %(asctime)s -  %(levelname)s -  %(message)s', handlers = [logging.StreamHandler()])
logging.getLogger().setLevel(logging.INFO)

print('Provide password to get acces to Keepass file:')
password = getpass.getpass()

try:  
    kp = PyKeePass(KEEPASS_FILE, password=password)
    logging.info('Keepass data loaded')
except:
    logging.exception('Cannot open the keepass file:')
# Out:
# Provide password to get acces to Keepass file:
#  ·········
#  2022-01-31 12:37:27,067 -  INFO -  Keepass data loaded

# %% [markdown]
# # Connection à la base de données

# %%
def connexion_setup(kp_con_name='SBX-RDS'):

    credential = kp.find_entries(title=kp_con_name, first=True)

    con = credential.url.split('//')[0] + '//' + \
    credential.username +':'+ \
    credential.password + \
    credential.url.split('//')[1]
    logging.debug(f'connexion string: {con}')

    con_engine = sqlalchemy.create_engine(con)

    return con_engine

# %%
#Read mapping file
VAR_MAPPING_FILE = Configuration_path/'10min_variables_iec_to_std_names_mapping.csv'
df = pd.read_csv(VAR_MAPPING_FILE)
df.head()

#Mapping dict
iec2std = df.loc[:,['iec_attribute61400','business_description']].set_index('iec_attribute61400')['business_description'].to_dict()
std2iec = df.loc[:,['iec_attribute61400','business_description']].set_index('business_description')['iec_attribute61400'].to_dict()

#Récupération des données utiles
mask_features = [False]
List_features = ['active_power_avg','wind_speed_avg']
for feature in List_features :
    mask_features = mask_features | (df.business_description == feature)
temperature_features = df.loc[mask_features,:]
features_selection_str = str(list(temperature_features.iec_attribute61400)).replace("'", '').replace("[", "").replace("]", "")

# %% [markdown]
# # Extraction de données

# %%
#Liste des projets à extraire
start_project = 'AUCO'
start_month = '2020-01'
end_month = '2021-11'

# %%
months_range = pd.date_range(start=start_month, end=end_month, freq='MS')
months_list = [str(months_range[i])[0:7] for i in range(len(months_range))]

#On récupère la liste des projets
List_projects = pd.read_csv(Path('/home/ec2-user/SageMaker/EtudeWindIndex/Data/list_projects.csv'),sep=';').project.tolist()
#List_projects = ['ESPS']

# %%
for PROJECT in List_projects :
    
    logging.info("project : {}".format(PROJECT))
    
    _10min_project = pd.DataFrame(columns=['asset_id','ts'] + List_features)
    
    #Number of WTGS in this project from WDM
    query = f'''SELECT project_code, iec_eqpt_code, wt_neighbor_01, power_curve_code
    FROM wdm.adm_eqpt_wt 
    WHERE project_code = '{PROJECT}' ;
    '''
    
    with connexion_setup('SBX-WDM').connect() as conn:
        wtg_eqpt_codes = pd.read_sql_query(sql=query, con=conn, params={})
    
    WTGS = tuple(wtg_eqpt_codes.iec_eqpt_code)
        
    #10 minutes data extraction
    for MONTH in months_list :
        
        logging.info("month : {}".format(MONTH))
        
        FROM_DATE =  MONTH + '-01 00:00:00'  # included
        if int(MONTH[-2:])==12:
            TO_DATE = f'{int(MONTH[:-3]) + 1}-01-01 00:00:00'      # not included 
        elif int(MONTH[-2:])>=9:
                TO_DATE = f'{MONTH[:-3]}-{int(MONTH[-2:]) + 1}-01 00:00:00'      # not included 
        else :
            TO_DATE = f'{MONTH[:-3]}-0{int(MONTH[-2:]) + 1}-01 00:00:00'      # not included 
            TO_DATE = f'2021-12-01 00:00:00'      # not included
            
        DATES = [d.strftime('%Y%m%d') for d in pd.date_range(FROM_DATE, TO_DATE)]
        _10min_tables = [f'eu_data.tur_10m_{date}_q' for date in DATES[:-1]]
        query = ""
        
        for i, table in enumerate(_10min_tables):
            if i != 0:
                query = query + "UNION\n"
            query = query + f'''SELECT  asset_id, 
            ts,
            {features_selection_str}
            FROM {table} WHERE project = '{PROJECT}' AND tech_source = 'PIOEM' \n'''
            
        query = query + "ORDER BY ts ;"
        
        with (connexion_setup('PWU-RSH').connect()) as conn:
            _10min = pd.read_sql_query(sql=query, con=conn)    # query_red(conn, query)
            
        _10min.rename(columns=iec2std, inplace=True)
        
        # re-order columns
        col_selection = _10min.columns.sort_values()
        _10min = _10min.loc[:,col_selection]
        
        _10min_project = pd.concat([_10min_project, _10min])
        
    #On converti le timestamp
    _10min_project['year'] = _10min_project.ts.map(lambda date: date.year)
    _10min_project['month'] = _10min_project.ts.map(lambda date: date.month)
    _10min_project['day'] = _10min_project.ts.map(lambda date: date.day)
    _10min_project['hour'] = _10min_project.ts.map(lambda date: date.hour)
    _10min_project['minute'] = _10min_project.ts.map(lambda date: date.minute)
    
    #On récupère le nom de projet et le numéro de turbine
    _10min_project['project'] = _10min_project.asset_id.map(lambda name: name[0:4])
    _10min_project['turbine'] = _10min_project.asset_id.map(lambda name: int(name[-3:]))
    
    #On garde les informations utiles
    _10min_project.drop(['asset_id','ts'], axis=1, inplace=True)
    #On modifie l'index pour retrouver plus facilement les données
    _10min_project.set_index(['project','turbine','year','month','day','hour','minute'], inplace=True)

    #Sauvegarde sur le notebook
    _10min_path = Path('/home/ec2-user/SageMaker/EtudeWindIndex/Data/Windga/WindGa_hourly/Clean/10min_'+PROJECT+'.csv')
    _10min_project.to_csv(_10min_path, index=False, sep=';')
    
    #Sauvegarde sur le S3
    outfile = '10min_'+PROJECT+'.csv'
    _10min_project.to_csv(f's3://{S3_bucket_name}/{S3_CSV_FOLD}/{outfile}', index=True, sep=';')
# Out:
#  2022-01-31 14:39:34,049 -  INFO -  project : AUQB
#  2022-01-31 14:39:34,102 -  INFO -  month : 2020-01
#  2022-01-31 14:42:24,609 -  INFO -  month : 2020-02
#  2022-01-31 14:45:02,761 -  INFO -  month : 2020-03
#  2022-01-31 14:47:29,994 -  INFO -  month : 2020-04
#  2022-01-31 14:49:45,327 -  INFO -  month : 2020-05
#  2022-01-31 14:51:51,679 -  INFO -  month : 2020-06
#  2022-01-31 14:53:49,360 -  INFO -  month : 2020-07
#  2022-01-31 14:55:40,875 -  INFO -  month : 2020-08
#  2022-01-31 14:57:21,089 -  INFO -  month : 2020-09
#  2022-01-31 14:57:25,964 -  INFO -  month : 2020-10
#  2022-01-31 14:57:31,330 -  INFO -  month : 2020-11
#  2022-01-31 14:57:36,664 -  INFO -  month : 2020-12
#  2022-01-31 14:57:41,563 -  INFO -  month : 2021-01
#  2022-01-31 14:59:04,324 -  INFO -  month : 2021-02
#  2022-01-31 15:00:13,530 -  INFO -  month : 2021-03
#  2022-01-31 15:01:09,986 -  INFO -  month : 2021-04
#  2022-01-31 15:02:01,160 -  INFO -  month : 2021-05
#  2022-01-31 15:02:41,450 -  INFO -  month : 2021-06
#  2022-01-31 15:03:15,401 -  INFO -  month : 2021-07
#  2022-01-31 15:03:25,552 -  INFO -  month : 2021-08
#  2022-01-31 15:03:31,652 -  INFO -  month : 2021-09
#  2022-01-31 15:03:33,229 -  INFO -  month : 2021-10
#  2022-01-31 15:03:34,948 -  INFO -  month : 2021-11
#  2022-01-31 15:06:14,948 -  INFO -  ascii passed initial chaos probing. Mean measured chaos is 0.000000 %
#  2022-01-31 15:06:14,949 -  INFO -  ascii should target any language(s) of ['Latin Based']
#  2022-01-31 15:06:14,953 -  INFO -  We detected language [('English', 0.9524), ('Indonesian', 0.9048), ('Simple English', 0.8571)] using ascii
#  2022-01-31 15:06:14,954 -  INFO -  ascii is most likely the one. Stopping the process.
#  2022-01-31 15:06:14,966 -  INFO -  ascii passed initial chaos probing. Mean measured chaos is 0.000000 %
#  2022-01-31 15:06:14,967 -  INFO -  ascii should target any language(s) of ['Latin Based']
#  2022-01-31 15:06:14,973 -  INFO -  We detected language [('German', 0.8333), ('Hungarian', 0.8333), ('Slovak', 0.8333), ('English', 0.75), ('Dutch', 0.75), ('Italian', 0.75), ('Swedish', 0.75), ('Norwegian', 0.75), ('Czech', 0.75), ('Indonesian', 0.75), ('Danish', 0.75), ('Polish', 0.6667), ('Finnish', 0.6667), ('Slovene', 0.6667), ('Turkish', 0.5833), ('Vietnamese', 0.5), ('Lithuanian', 0.5)] using ascii
#  2022-01-31 15:06:14,974 -  INFO -  ascii is most likely the one. Stopping the process.
#  2022-01-31 15:06:15,011 -  INFO -  ascii passed initial chaos probing. Mean measured chaos is 0.000000 %
#  2022-01-31 15:06:15,014 -  INFO -  ascii should target any language(s) of ['Latin Based']
#  2022-01-31 15:06:15,017 -  INFO -  We detected language [('English', 1.0), ('Indonesian', 1.0), ('Simple English', 1.0)] using ascii
#  2022-01-31 15:06:15,023 -  INFO -  ascii is most likely the one. Stopping the process.
#  2022-01-31 15:06:42,426 -  INFO -  project : AMEL
#  2022-01-31 15:06:42,460 -  INFO -  month : 2020-01
#  2022-01-31 15:09:33,270 -  INFO -  month : 2020-02
#  2022-01-31 15:12:10,389 -  INFO -  month : 2020-03
#  2022-01-31 15:14:37,382 -  INFO -  month : 2020-04
#  2022-01-31 15:16:52,876 -  INFO -  month : 2020-05
#  2022-01-31 15:19:46,830 -  INFO -  month : 2020-06
#  2022-01-31 15:21:48,104 -  INFO -  month : 2020-07
#  2022-01-31 15:23:39,172 -  INFO -  month : 2020-08
#  2022-01-31 15:25:20,266 -  INFO -  month : 2020-09
#  2022-01-31 15:25:20,652 -  INFO -  month : 2020-10
#  2022-01-31 15:25:20,908 -  INFO -  month : 2020-11
#  2022-01-31 15:25:21,192 -  INFO -  month : 2020-12
#  2022-01-31 15:25:21,600 -  INFO -  month : 2021-01
#  2022-01-31 15:26:26,258 -  INFO -  month : 2021-02
#  2022-01-31 15:27:24,615 -  INFO -  month : 2021-03
#  2022-01-31 15:28:16,770 -  INFO -  month : 2021-04
#  2022-01-31 15:29:02,884 -  INFO -  month : 2021-05
#  2022-01-31 15:29:47,298 -  INFO -  month : 2021-06
#  2022-01-31 15:30:21,336 -  INFO -  month : 2021-07
#  2022-01-31 15:30:31,742 -  INFO -  month : 2021-08
#  2022-01-31 15:30:37,770 -  INFO -  month : 2021-09
#  2022-01-31 15:30:38,297 -  INFO -  month : 2021-10
#  2022-01-31 15:30:48,921 -  INFO -  month : 2021-11
#  2022-01-31 15:33:13,987 -  INFO -  project : BOUS
#  2022-01-31 15:33:14,022 -  INFO -  month : 2020-01
#  2022-01-31 15:36:40,359 -  INFO -  month : 2020-02
#  2022-01-31 15:39:20,173 -  INFO -  month : 2020-03
#  2022-01-31 15:41:50,369 -  INFO -  month : 2020-04
#  2022-01-31 15:44:08,396 -  INFO -  month : 2020-05
#  2022-01-31 15:46:59,088 -  INFO -  month : 2020-06
#  2022-01-31 15:49:02,061 -  INFO -  month : 2020-07
#  2022-01-31 15:50:49,718 -  INFO -  month : 2020-08
#  2022-01-31 15:52:30,284 -  INFO -  month : 2020-09
#  2022-01-31 15:52:35,140 -  INFO -  month : 2020-10
#  2022-01-31 15:52:40,153 -  INFO -  month : 2020-11
#  2022-01-31 15:52:44,878 -  INFO -  month : 2020-12
#  2022-01-31 15:52:49,658 -  INFO -  month : 2021-01
#  2022-01-31 15:53:55,859 -  INFO -  month : 2021-02
#  2022-01-31 15:54:59,483 -  INFO -  month : 2021-03
#  2022-01-31 15:55:50,982 -  INFO -  month : 2021-04
#  2022-01-31 15:56:37,771 -  INFO -  month : 2021-05
#  2022-01-31 15:57:17,429 -  INFO -  month : 2021-06
#  2022-01-31 15:57:50,816 -  INFO -  month : 2021-07
#  2022-01-31 15:58:01,281 -  INFO -  month : 2021-08
#  2022-01-31 15:58:07,179 -  INFO -  month : 2021-09
#  2022-01-31 15:58:08,764 -  INFO -  month : 2021-10
#  2022-01-31 15:58:10,404 -  INFO -  month : 2021-11
#  2022-01-31 15:59:48,224 -  INFO -  ascii passed initial chaos probing. Mean measured chaos is 0.000000 %
#  2022-01-31 15:59:48,228 -  INFO -  ascii should target any language(s) of ['Latin Based']
#  2022-01-31 15:59:48,231 -  INFO -  We detected language [('Indonesian', 1.0), ('Simple English', 1.0), ('English', 0.9524)] using ascii
#  2022-01-31 15:59:48,232 -  INFO -  ascii is most likely the one. Stopping the process.
#  2022-01-31 15:59:48,242 -  INFO -  ascii passed initial chaos probing. Mean measured chaos is 0.000000 %
#  2022-01-31 15:59:48,242 -  INFO -  ascii should target any language(s) of ['Latin Based']
#  2022-01-31 15:59:48,245 -  INFO -  We detected language [('German', 0.8333), ('Hungarian', 0.8333), ('Slovak', 0.8333), ('English', 0.75), ('Dutch', 0.75), ('Italian', 0.75), ('Swedish', 0.75), ('Norwegian', 0.75), ('Czech', 0.75), ('Indonesian', 0.75), ('Danish', 0.75), ('Polish', 0.6667), ('Finnish', 0.6667), ('Slovene', 0.6667), ('Turkish', 0.5833), ('Vietnamese', 0.5), ('Lithuanian', 0.5)] using ascii
#  2022-01-31 15:59:48,246 -  INFO -  ascii is most likely the one. Stopping the process.
#  2022-01-31 15:59:48,257 -  INFO -  ascii passed initial chaos probing. Mean measured chaos is 0.000000 %
#  2022-01-31 15:59:48,258 -  INFO -  ascii should target any language(s) of ['Latin Based']
#  2022-01-31 15:59:48,262 -  INFO -  We detected language [('English', 1.0), ('Indonesian', 1.0), ('Simple English', 1.0)] using ascii
#  2022-01-31 15:59:48,263 -  INFO -  ascii is most likely the one. Stopping the process.
#  2022-01-31 16:00:09,254 -  INFO -  project : BRIY
#  2022-01-31 16:00:09,280 -  INFO -  month : 2020-01
#  2022-01-31 16:02:56,514 -  INFO -  month : 2020-02
#  2022-01-31 16:05:32,652 -  INFO -  month : 2020-03
#  2022-01-31 16:08:03,582 -  INFO -  month : 2020-04
#  2022-01-31 16:10:19,231 -  INFO -  month : 2020-05
#  2022-01-31 16:12:36,554 -  INFO -  month : 2020-06
#  2022-01-31 16:14:32,449 -  INFO -  month : 2020-07
#  2022-01-31 16:16:21,205 -  INFO -  month : 2020-08
#  2022-01-31 16:18:06,592 -  INFO -  month : 2020-09
#  2022-01-31 16:18:11,334 -  INFO -  month : 2020-10
#  2022-01-31 16:18:16,364 -  INFO -  month : 2020-11
#  2022-01-31 16:18:21,014 -  INFO -  month : 2020-12
#  2022-01-31 16:18:26,017 -  INFO -  month : 2021-01
#  2022-01-31 16:19:33,073 -  INFO -  month : 2021-02
#  2022-01-31 16:20:33,169 -  INFO -  month : 2021-03
#  2022-01-31 16:21:25,558 -  INFO -  month : 2021-04
#  2022-01-31 16:22:10,657 -  INFO -  month : 2021-05
#  2022-01-31 16:22:51,502 -  INFO -  month : 2021-06
#  2022-01-31 16:23:25,674 -  INFO -  month : 2021-07
#  2022-01-31 16:23:36,023 -  INFO -  month : 2021-08
#  2022-01-31 16:23:41,668 -  INFO -  month : 2021-09
#  2022-01-31 16:23:43,183 -  INFO -  month : 2021-10
#  2022-01-31 16:23:44,635 -  INFO -  month : 2021-11
#  2022-01-31 16:24:58,359 -  INFO -  ascii passed initial chaos probing. Mean measured chaos is 0.000000 %
#  2022-01-31 16:24:58,360 -  INFO -  ascii should target any language(s) of ['Latin Based']
#  2022-01-31 16:24:58,361 -  INFO -  We detected language [('English', 1.0), ('Indonesian', 1.0), ('Simple English', 1.0)] using ascii
#  2022-01-31 16:24:58,362 -  INFO -  ascii is most likely the one. Stopping the process.
#  2022-01-31 16:24:58,368 -  INFO -  ascii passed initial chaos probing. Mean measured chaos is 0.000000 %
#  2022-01-31 16:24:58,369 -  INFO -  ascii should target any language(s) of ['Latin Based']
#  2022-01-31 16:24:58,370 -  INFO -  We detected language [('German', 0.8333), ('Hungarian', 0.8333), ('Slovak', 0.8333), ('English', 0.75), ('Dutch', 0.75), ('Italian', 0.75), ('Swedish', 0.75), ('Norwegian', 0.75), ('Czech', 0.75), ('Indonesian', 0.75), ('Danish', 0.75), ('Polish', 0.6667), ('Finnish', 0.6667), ('Slovene', 0.6667), ('Turkish', 0.5833), ('Vietnamese', 0.5), ('Lithuanian', 0.5)] using ascii
#  2022-01-31 16:24:58,371 -  INFO -  ascii is most likely the one. Stopping the process.
#  2022-01-31 16:24:58,382 -  INFO -  ascii passed initial chaos probing. Mean measured chaos is 0.000000 %
#  2022-01-31 16:24:58,383 -  INFO -  ascii should target any language(s) of ['Latin Based']
#  2022-01-31 16:24:58,386 -  INFO -  We detected language [('English', 1.0), ('Indonesian', 1.0), ('Simple English', 1.0)] using ascii
#  2022-01-31 16:24:58,386 -  INFO -  ascii is most likely the one. Stopping the process.
#  2022-01-31 16:25:13,724 -  INFO -  project : CLIT
#  2022-01-31 16:25:13,751 -  INFO -  month : 2020-01
#  2022-01-31 16:27:43,366 -  INFO -  month : 2020-02
#  2022-01-31 16:30:02,291 -  INFO -  month : 2020-03
#  2022-01-31 16:32:12,804 -  INFO -  month : 2020-04
#  2022-01-31 16:34:12,878 -  INFO -  month : 2020-05
#  2022-01-31 16:36:03,784 -  INFO -  month : 2020-06
#  2022-01-31 16:37:48,655 -  INFO -  month : 2020-07
#  2022-01-31 16:39:24,487 -  INFO -  month : 2020-08
#  2022-01-31 16:40:52,643 -  INFO -  month : 2020-09
#  2022-01-31 16:40:57,122 -  INFO -  month : 2020-10
#  2022-01-31 16:41:01,668 -  INFO -  month : 2020-11
#  2022-01-31 16:41:06,030 -  INFO -  month : 2020-12
#  2022-01-31 16:41:10,567 -  INFO -  month : 2021-01
#  2022-01-31 16:42:06,931 -  INFO -  month : 2021-02
#  2022-01-31 16:42:58,203 -  INFO -  month : 2021-03
#  2022-01-31 16:44:09,399 -  INFO -  month : 2021-04
#  2022-01-31 16:45:08,071 -  INFO -  month : 2021-05
#  2022-01-31 16:45:48,653 -  INFO -  month : 2021-06
#  2022-01-31 16:46:16,882 -  INFO -  month : 2021-07
#  2022-01-31 16:46:22,509 -  INFO -  month : 2021-08
#  2022-01-31 16:46:26,689 -  INFO -  month : 2021-09
#  2022-01-31 16:46:27,707 -  INFO -  month : 2021-10
#  2022-01-31 16:46:28,713 -  INFO -  month : 2021-11
#  2022-01-31 16:46:31,474 -  INFO -  project : AUCO
#  2022-01-31 16:46:31,512 -  INFO -  month : 2020-01
#  2022-01-31 16:49:18,494 -  INFO -  month : 2020-02
